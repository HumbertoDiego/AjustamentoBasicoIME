# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HumbertoDiego/AjustamentoBasicoIME/blob/main/UD_I_e_II_01_ajustamento_observacoes.ipynb)

# %% [markdown]
# # Ajustamento Básico - Visão geral sobre ajustamento de observações
#
# **Maj Diego - 2° Semestre / 2026**
#
# **Objetivos**
#
# 1. Enunciar as bases do ajustamento de observações.
# 2. Conceituar o ajustamento das observações.
# 3. Conceituar modelos matemáticos, observações e medidas.
#
# **Referência:** Ghilani, C. D. (2017). *Adjustment computations: Spatial data analysis* (6th ed.). Wiley.

# %% [markdown]
# ## O Problema
#
# <img src="media/imgs/img0.png" width=800>

# %% [markdown]
# ## 1. O Ajustamento de Observações
#
# ### **1.1 O mundo aproximado das ciênicas exatas**
#
# O ajustamento nasce da constatação de que <b style="color:#CC2E40"> observações reais contêm erros de medida</b>.
#
# <img src="media/imgs/img1.jpeg" width=600>

# %% [markdown]
# **Exercício 01:** E aí tio João?
#
# |<img src="media/imgs/tiojoao.png" height=500>| Qual o peso (massa) líquido contido nesta embalagem?<br>- É exatamente 1,0000000 kg?<br>- É possível repetir exatamente mesmas condições de medição? Temperatura, umidade..<br>- Qual equipamento fornece a resposta mais precisa? |
# |-|-|

# %% [markdown]
# **Exercício 02:** Qual o último algarismo confiável da medição?
#
# |<img src="media/imgs/img2.jpeg" width=400>|$\begin{cases}x = 15.1mm \\ x = 16.0mm \\ x = 15.5mm \\ x = 15.4mm \\ \vdots\end{cases}$|
# |-|-|
#
# É convencionado que o desvio-padrão de uma régua é metade da sua menor divisão. Assim, no caso da régua da figura, a incerteza pela convenção é $\pm 0.5 mm$ que define o último algarismo confiável da medição.

# %% [markdown]
# ### **1.1 Conceito de ajustamento das observações**
#
# **Ajustamento** é o ramo da matemática aplicada que busca uma <b style="color:#2ECC40">solução aproximada (idealmente única)</b> para <b  style="color:#ffff00">sistemas inconsistentes</b>, admitindo resíduos nas observações e estimando a qualidade da solução obtida.
#
# Em termos práticos, ajustar significa **acomodar um conjunto de observações por meio de um modelo matemático**, de modo que o vetor solução represente a **melhor estimativa** para os parâmetros desconhecidos.
#
# Se os erros não existissem, bastaria resolver sistemas exatos por álgebra linear usual. Como isso não ocorre na prática, aparecem sistemas <b  style="color:#ffff00">inconsistentes</b> e, por isso, é necessário ajustar as observações.

# %% [markdown]
# ### **1.2 Conceito de medidas, observações e modelos matemáticos**
#
# <img src=media/imgs/medidas.png width=800>
#
# **Medida**: operação física de comparação com um padrão. O resultado desta medida (leitura) é a observação. Exemplos: Medidas de ângulos, de distâncias, da temperatura... etc.
# - **Medida direta**: direta sobre grandeza procurada. Ex: distância ou ângulo isolado
# - **Medida indireta**: cálculo das incógnitas (parâmetros) por meio de relações matemáticas de medidas diretas. Os erros de medida nas observações são propagados para os parâmetros. Ex: área e coordenadas.

# %% [markdown]
# **Exercício 04:** Nivelamento Trigonométrico
#
# <img src=media/imgs/img3.jpeg width=800>
#
# Medidas diretas?
#
# <!-- zênite (Z), distância laser (s), Alturas ET e Prisma -->
#
# Medidas indiretas?

# %% [markdown]
# <!-- Cota B -->
#
# **Observação**: resultado numérico da medida (a leitura), já afetado por flutuações probabilísticas. Contém erros que decorrem não apenas de **falhas humanas**, mas também da **imperfeição do equipamento**; da influência das **condições ambientais** nas quais se processa a
# mensuração, e outros **efeitos aleatórios** sem causa específica. São medidas de qualidade das observações a precisão e a acurácia, vistos posteriormente.
#
# **Modelo matemático**: conjunto de relações que representa o fenômeno observado.

# %% [markdown]
# - **modelo funcional**: descreve as relações determinísticas, ou seja, completamente previsíveis, entre observações e parâmetros. Por exemplo, a soma dos ângulos internos de um triângulo ($ABC$) possui uma modelagem funcional: $A+B+C=180^\circ$
# - **modelo estocástico**: descreve o comportamento probabilístico das observações, ou seja, enquadra a aleatoriedade do evento através de suas dispersões e variâncias. Por exemplo, as inúmeros medições da massa do pacote de arroz constrói uma amostragem cujo modelo estocástico é equivalente à distribuição gaussiana.
#
# > Nota: Relembre que a distribuição gaussiana, ou normal, é uma distribuição de probabilidade contínua em forma de sino, definida pela média $\mu$ e pelo desvio padrão $\sigma$, amplamente utilizada para modelar fenômenos naturais e erros de medição. Nela, dada a distribuição de uma amostra, infere-se que dentre $\mu \pm 1\sigma$ se encontra 68% da população, dentre $2\sigma$, 95% e dentre $3\sigma$, 99,7% da população (Regra 68-95-99.7).
